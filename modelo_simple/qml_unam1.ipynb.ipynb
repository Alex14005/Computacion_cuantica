# %%
# Out:
# Costo final de entrenamiento 0.007594
# Precisión final de entrenamiento 0.993333

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 ## Ejemplo sencillo variacional
# ----> 3 from qiskit import QuantumCircuit
#       4 import qiskit.quantum_info as qi
#       5 from qiskit.visualization import plot_bloch_multivector
#
# ModuleNotFoundError: No module named 'qiskit'

# %%
from qiskit import QuantumCircuit
print("Qiskit está funcionando correctamente.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from qiskit import QuantumCircuit
#       2 print("Qiskit está funcionando correctamente.")
#
# ModuleNotFoundError: No module named 'qiskit'
